# %%
#Nicole Hwang
#nhwang1
#1
import folium
import requests
import pandas

arrest_table = pandas.read_csv("http://www.hcbravo.org/IntroDataSci/misc/BPD_Arrests.csv")

arrest_table["race_new"] = arrest_table["sex"]
arrest_table["sex_new"] = arrest_table["race"]
arrest_table["race"] = arrest_table["race_new"]
arrest_table["sex"] = arrest_table["sex_new"]
arrest_table = arrest_table.drop('race_new', 1)
arrest_table = arrest_table.drop('sex_new', 1)

arrest_table = arrest_table[pandas.notnull(arrest_table["Location 1"])]

arrest_table["lat"], arrest_table["long"] = arrest_table["Location 1"].str.split(",").str
arrest_table["lat"] = arrest_table["lat"].str.replace("(", "").astype(float)
arrest_table["long"] = arrest_table["long"].str.replace(")", "").astype(float)

arrest_table.head()
# Out:
#        arrest  age sex race  arrestDate arrestTime     arrestLocation  \
# 1  11127013.0   37   M    B  01/01/2011      00:01   2000 Wilkens Ave
# 2  11126887.0   46   M    B  01/01/2011      00:01  2800 Mayfield Ave
# 3  11126873.0   50   M    B  01/01/2011      00:04  2100 Ashburton St
# 4  11126968.0   33   M    B  01/01/2011      00:05    4000 Wilsby Ave
# 5  11127041.0   41   M    B  01/01/2011      00:05   2900 Spellman Rd
#
#          incidentOffense          incidentLocation  charge  \
# 1               79-Other  Wilkens Av & S Payson St  1 1425
# 2        Unknown Offense                       NaN     NaN
# 3               79-Other         2100 Ashburton St  1 1106
# 4        Unknown Offense         1700 Aliceanna St     NaN
# 5  81-Recovered Property           2900 Spelman Rd  1 1425
#
#                              chargeDescription      district   post  \
# 1  Reckless Endangerment || Hand Gun Violation      SOUTHERN  934.0
# ...

# %%
#2
map_osm = folium.Map(location=[39.29, -76.61], zoom_start=11)
map_osm
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#3

sample = arrest_table.sample(300, replace=True)

map_1 = folium.Map(location=[39.29, -76.61], zoom_start=12)
map_2 = folium.Map(location=[39.29, -76.61], zoom_start=12)
for row in sample.iterrows(): 
    info = 'arrestTime:'+ str(row[1]['arrestTime'])+' neighborhood:'+ str(row[1]['neighborhood'])
    if(row[1]['sex'] =='M'):
          folium.CircleMarker([row[1]['lat'], row[1]['long']], radius=7, fill_color='blue',color = 'blue').add_to(map_1)
    if(row[1]['sex'] =='F'):
        folium.CircleMarker([row[1]['lat'], row[1]['long']], radius=7, fill_color='red',color = 'red').add_to(map_1)
    if(row[1]['race'] == 'B'):
        folium.Marker([row[1]['lat'], row[1]['long']], icon=folium.Icon(color='black'),popup=info).add_to(map_2)
    if(row[1]['race'] == 'W'):
        folium.Marker([row[1]['lat'], row[1]['long']], icon=folium.Icon(color='red'),popup=info).add_to(map_2)
    if(row[1]['race'] == 'A'):
        folium.Marker([row[1]['lat'], row[1]['long']], icon=folium.Icon(color='yellow'),popup=info).add_to(map_2)
    if(row[1]['race'] == 'H'):
        folium.Marker([row[1]['lat'], row[1]['long']], icon=folium.Icon(color='blue'),popup=info).add_to(map_2)
map_1
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
map_2
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# I have created two maps using the same random 300 samples from the large data I have given. For map_1, I have marked the crime by sex with red circle representing female and blue circle representing make.
# For map_2, I have maked the crime by race with red indicting white and black indicting black. Although I am also trying to find race of other, my sample usually did not include Asian and Hispanic because the cases are dramically less.
#
# By just looking at the map, we can see that Balitmore crime is more likely to cause by male and black people.
